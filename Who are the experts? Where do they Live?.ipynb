# %% [markdown]
# # Who are the Experts?

# %%
import pandas as pd
import numpy as np

# %%
Users=pd.read_csv("../UsersWithCountry.csv")
Users
# Out:
#          userId  Reputation         Country
# 0             1     41626.0   United States
# 1             2      3100.0   United States
# 2             3     13028.0   United States
# 3             4     27501.0   United States
# 4             5     37057.0   United States
# 5             9     12872.0   United States
# 6            10       101.0   United States
# 7            13    164224.0   United States
# 8            16       497.0          Brazil
# 9            17     41961.0   United States
# 10           19      1097.0         Denmark
# 11           20      7801.0   United States
# 12           22     10705.0          Canada
# 13           23      3691.0   United States
# 14           24      2531.0  United Kingdom
# 15           25     15159.0   United States
# 16           26     10755.0   United States
# 17           27      1246.0   United States
# 18           29     66001.0   United States
# 19           30      7708.0         Georgia
# ...

# %%
Experts=GetScaledReputation(Users)

# %%
def GetScaledReputaion:
    #the dicts with weights
    for userid in Users['userId'].values:
        Users["Scaled Reputation"].loc[Users['userId']==userid]=Users["Reputation"].loc[Users['userId']==userid]

# %%
Users['userId'].values
# Out:
# array([      1,       2,       3, ..., 8522063, 8522138, 8522152])

# %%
MigrationUSData["Country"].loc[MigrationUSData["Country"]=='North and South Korea']='North Korea'
