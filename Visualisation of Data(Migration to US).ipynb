# 4      225              Eritrea
# 5     1399             Ethiopia
# 6     1545                Ghana
# 7     1626                Kenya
# 8      666              Liberia
# 9     1105              Morocco
# 10    3541              Nigeria
# 11     260         Sierra Leone
# 12     400              Somalia
# 13    2824         South Africa
# 14     133              Senegal
# 15     313                Sudan
# 16     562               Uganda
# 17     482             Tanzania
# 18     419             Zimbabwe
# 19   29123              Vietnam
# 20     182                Yemen
# 21     798           Uzbekistan
# 22    1323            Sri Lanka
# 23     673                Syria
# 24    3039             Thailand
# 25    3149          South Korea
# 26    1157            Singapore
# 27     587         Saudi Arabia
# 28   12121          North Korea
# 29    8600             Pakistan
# ..     ...                  ...
# 94    2812            Venezuela
# 95    2337               Panama
# 96     175             Paraguay
# 97    3637                 Peru
# 98    8241          Puerto Rico
# 99     200          Saint Lucia
# 100   2343  Trinidad and Tobago
# 101    313              Uruguay
# 102   1893            Guatemala
# 103    959             Honduras
# 104   6271              Jamaica
# 105    249              Grenada
# 106   2473               Guyana
# 107   2540                Haiti
# 108  15444               Mexico
# 109   1307            Nicaragua
# 110    726           Costa Rica
# 111   5009             Colombia
# 112   5597                 Cuba
# 113   1098                Chile
# 114    169             Dominica
# 115   2735   Dominican Republic
# 116   2005              Ecuador
# 117   1970            Argentina
# 118    627              Bolivia
# 119   3891               Brazil
# 120    345               Belize
# 121    250              Bermuda
# 122    699             Barbados
# 123    271              Bahamas
#
# [123 rows x 4 columns]

# %%
Locations=MigrationUSData.to_dict()["Country"]
Value=MigrationUSData.to_dict()["Value"]

# %%
CountryList=list(Locations.values())
CountryValues=list(Value.values())

# %%
import numpy as np
import pycountry
from geotext import GeoText

keys=pd.read_csv("../KeyCountry.csv")
def GetKeys(CountryList):
    KeyList=([])
    for text in CountryList:
        places = GeoText(text)
        
        if len(places.country_mentions)>0:
            CountryCode=list(places.country_mentions.keys())
            Country = pycountry.countries.get(alpha_2=CountryCode[0])
            KeyList=np.append(KeyList,Country.alpha_3)
    return KeyList

# %%
trial=GetKeys(CountryList)
trial.size
# Out:
# 123

# %%
import plotly.plotly as py
dataUS = [ dict(
        type = 'choropleth',
        locations = trial,
        z = CountryValues,
        text = CountryList,
       # colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
           # [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = True,
        reversescale = False,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            tickprefix = '',
            title = 'Users'),
      ) ]

layoutUS = dict(
    title = 'Heat Map of Migration to US',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=dataUS, layout=layoutUS )
py.iplot( fig, validate=False, filename='d3world-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~a-parida12/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Knowledge Transfer in StackOverflow

# %% [markdown]
# ## Why Should Anyone Care ?
# * Influence to job market

# %% [markdown]
# ## Research Question
# * Knowledge Transfer and Migration of Skilled Labor

# %% [markdown]
# ## Data Source
# * StackOverflow Data Dump
# * OECD Migration Data for USA

# %% [markdown]
# ## Data Analysis
# * Modelling Experts
# * Mapping of Questions and Answers

# %%
## Some Visualisation
