# %% [markdown]
# # Import all Modules and CSV

# %%
import pandas as pd
import numpy as np

# %%
Users=pd.read_csv("../Users.csv",sep='\t',lineterminator='\r',names=['userId','Reputation','Location'])
Users=Users.dropna(axis=0, how='any')
Users=Users.loc[Users['Reputation']>1]
Users=Users.loc[Users['Location']!='Unknown']
Users['Country']='NP'

# %%
len(Users)
# Out:
# 712966

# %% [markdown]
# # Clean up the UserID

# %%
def UserIdClearner(text):
    text=text.strip()
    text=text.replace('"',"")
    text=text.strip()
    text=text.replace('"',"")
    
    return int(text)

# %%
Users["userId"]=Users["userId"].apply(UserIdClearner)

# %% [markdown]
# # Getting User Country
#
# ## Using the major country list

# %%
CountryList=['United States', 'Afghanistan', 'Albania', 'Algeria',
       'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica',
       'Antigua And Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia',
       'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
       'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
       'Bhutan', 'Bolivia', 'Bosnia And Herzegowina', 'Botswana',
       'Bouvet Island', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
       'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada',
       'Cape Verde', 'Cayman Islands', 'Central African Rep', 'Chad',
       'Chile', 'China', 'Christmas Island', 'Cocos Islands', 'Colombia',
       'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Cote D`ivoire',
       'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark',
       'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor',
       'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
       'Estonia', 'Ethiopia', 'Falkland Islands',
       'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana',
       'French Polynesia',  'Gabon', 'Gambia',
       'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
       'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guinea',
       'Guinea-bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong',
       'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq',
       'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
       'Kazakhstan', 'Kenya', 'Kiribati', 'North Korea', 'South Korea',
       'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
       'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
       'Macau', 'Macedonia', 'Madagascar', 'Malawi', 'Malaysia',
       'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique',
       'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia',
       'Moldova', 'Monaco', 'Mongolia', 'Montserrat', 'Morocco',
       'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
       'Netherlands Antilles', 'New Caledonia', 'New Zealand', 'Nicaragua',
       'Niger', 'Nigeria', 'Niue', 'Norfolk Island',
       'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau',
       'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
       'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Reunion',
       'Romania', 'Russia', 'Rwanda', 'Saint Kitts And Nevis',
       'Saint Lucia', 'St Vincent/Grenadines', 'Samoa', 'San Marino',
       'Sao Tome', 'Saudi Arabia', 'Senegal', 'Seychelles', 'Sierra Leone',
       'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia',
       'South Africa', 'Spain', 'Sri Lanka', 'St. Helena', 'St.Pierre',
       'Sudan', 'Suriname', 'Swaziland', 'Sweden', 'Switzerland',
     'Taiwan', 'Tajikistan', 'Tanzania',
       'Thailand', 'Togo', 'Tokelau', 'Tonga', 'Trinidad And Tobago',
       'Tunisia', 'Turkey', 'Turkmenistan', 'Tuvalu', 'Uganda', 'Ukraine',
       'United Arab Emirates', 'United Kingdom', 'Uruguay', 'Uzbekistan',
       'Vanuatu', 'Vatican City State', 'Venezuela','Vietnam',
       'Virgin Islands', 'Syria',
       'Western Sahara', 'Yemen', 'Zaire', 'Zambia',
       'Zimbabwe']

# %%
import string
#CountryList=['India','New Zealand','Turkey','Denmark','Norway','Spain','Portugal' ,'Germany', 'Pakistan','United Kingdom', 'France', 'Netherlands', 'United States','Malaysia','Japan','Indonesia', 'Canada','Singapore','Belgium', 'Brazil','Ukraine', 'Russia', 'Sweden', 'China', 'Poland', 'Israel', 'Australia']
def GetCountryNaive(location):
    check=location.split(',')
    Country= check[-1].replace('"',"")
    Country=Country.strip()
    
    if Country=='UK'or Country=='England'or Country=='Scotland' or Country=='Wales':
        Country='United Kingdom'
    elif Country=='US' or Country=='USA'or Country=='United States of America':
        Country='United States'
    elif Country=='Brasil':
        Country='Brazil'  
    elif Country=='Deutschland':
        Country='Germany'  
    elif Country=='Viet Nam':
        Country='Vietnam' 
    if Country in CountryList:
        return Country
    else:
        check=Country.split(' ')
        if len(check)>2:
            Country= check[-2]+' '+check[-1].replace('"',"")
            if Country in CountryList:
                return Country
        else:
            Country=check[-1].replace('"',"")
        if Country in CountryList:
            return Country
        if check[-1].strip() in CountryList:
            return check[-1].strip()
        else:
            return 'NP'

# %%
Users["Country"]=Users["Location"].apply(GetCountryNaive)

# %% [markdown]
# ## Using the States of United States- Full/Short

# %%
USList=states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY" ]

USListState=["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming","San Fransisco"]

CanadaList=['YT','PE','BC','AB','ON','NB','SK','NS','QC','MB']
def GetStatesUSnCanadaNaive(location):
    check=location.split(',')
    Country= check[-1].replace('"',"")
    Country=Country.strip()
        
    if Country in USList:
        return 'United States'
    
    if Country in CanadaList:
        return 'Canada'
    
    if Country in USListState:
        return 'United States'
    
    else:
        check=Country.split(' ')
        if len(check)>2:
            Country= check[-2]+' '+check[-1].replace('"',"")
        else:
            Country=check[-1].replace('"',"")
        if Country in USListState:
            return 'United States'
        if check[-1] in USListState:
            return 'United States'
        else:
            return 'NP'

# %%
RemainUsers=Users[:].loc[Users["Country"]=='NP']
DoneUsers=Users[:].loc[Users["Country"]!='NP']
RemainUsers["Country"]=RemainUsers["Location"].apply(GetStatesUSnCanadaNaive)

# %%
Users=pd.concat([DoneUsers, RemainUsers])
Users=Users.sort_values(by='userId')

# %%
RemainUsers=Users[:].loc[Users["Country"]=='NP']
DoneUsers=Users[:].loc[Users["Country"]!='NP']

# %%
from geotext import GeoText
import pycountry
def CheckCountryorCity(text):
    places = GeoText(text)
    if len(places.cities)>0:
        CountryCode=list(places.country_mentions.keys())
        if CountryCode[0]== 'XK':
            return 'Kosovo'
        if CountryCode[0]== 'UK':
            return 'United Kingdom'
        Country = pycountry.countries.get(alpha_2=CountryCode[0])
        return Country.name
    if len(places.country_mentions)>0:
        CountryCode=list(places.country_mentions.keys())
        if CountryCode[0]== 'XK':
            return 'Kosovo'
        if CountryCode[0]== 'UK':
            return 'United Kingdom'
        Country = pycountry.countries.get(alpha_2=CountryCode[0])
        return Country.name

    return 'Check'

# %%
def SpellChecks(text):
    if text=='Russian Federartio':
        return 'Russia'
    if text=='Venezuela, Bolivarian Republic of':
        return 'Venezuala'
    if text=='Czechia':
        return 'Czech Republic'
    if text=='Korea, Republic of':
        return 'South Korea'
    if text=='Iran, Islamic Republic of':
        return 'Iran'
    if text=='Taiwan, Province of China':
        return 'Taiwan'
    if text=='Moldova, Republic of':
        return 'Moldova'
    if text=='Bolivia, Plurinational State of':
        return 'Bolivia'
    if text=='Syrian Arab Republic':
        return 'Syria'
    if text=="Korea, Democratic People's Republic of":
        return 'North Korea'
    if text=="Congo, The Democratic Republic of the":
        return 'Congo'
    if text=="Tanzania, United Republic of":
        return 'Tanzania'
    if text=="Lao People's Democratic Republic":
        return 'Laos'
    else:
        return text

# %%
RemainUsers["Country"]=RemainUsers["Location"].apply(CheckCountryorCity)

# %%
Users=pd.concat([DoneUsers, RemainUsers])
Users=Users.sort_values(by='userId')

# %%
#RemainUsers=Users[:].loc[Users["Country"]=='Check']
Users=Users[:].loc[Users["Country"]!='Check']

# %%
Users["Country"]=Users["Country"].apply(SpellChecks)

# %%
Users.head()
# Out:
#    userId  Reputation                       Location        Country
# 2       1     41626.0                El Cerrito, CA"  United States
# 3       2      3100.0  Corvallis, OR, United States"  United States
# 4       3     13028.0    Raleigh, NC, United States"  United States
# 5       4     27501.0                  New York, NY"  United States
# 6       5     37057.0                 San Diego, CA"  United States

# %%
CountryStat=pd.DataFrame(Users.Country.value_counts())
CountryStat.to_csv("../UsersLocationWise.csv")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
CountryStat.plot.pie(y=0)
plt.show()

# %%
plt.hist(DoneUsers['Reputation'],bins=10)#,normed=True)
#plt.xlabel('Review Rating')
#plt.ylabel('Instances')
#plt.title("The Park Grand London Paddington");
data=DoneUsers['Reputation'].values
fit = stats.norm.pdf(data, DoneUsers['Reputation'].mean(), DoneUsers['Reputation'].std())  #this is a fitting indeed

#plt.plot(DoneUsers['Reputation'],fit,'o')

# %%
Users.quantile(.83)
Top17pcUsers=Users.loc[Users['Reputation']>644]
Top17pcUsers.to_csv("../Top17pcUsers.csv",index= False)

# %%
Users.quantile(.17)
Bottom17pcUsers=Users.loc[Users['Reputation']<11]
Bottom17pcUsers.to_csv("../Bottom17pcUsers.csv",index= False)

# %%
Users.to_csv("../UsersWithCountry.csv",index= False)

# %% [markdown]
# # STOP!!!! UNDERCONSTRUCTION !!!!! ACHTUNG

# %% [markdown]
# Yet to be processed on the remaining Remain Users!!
#
# Also has my Sandbox!!

# %%
Country = np.array([])
from geopy.geocoders import Nominatim

def GetCountry(location):
    geolocator = Nominatim(timeout=10)
    location = geolocator.geocode(location,language='en')
    if location==None :
        return ('NP')
    splitstring=location.address.split(',')
    country=splitstring[-1]
    return country

# %%
def my_range(start, end, step):
    while start <= end:
        yield start
        start += step

# %%
for i in my_range(Country.size, len(RemainUsers)-1, 1):
    Country=np.append(Country,GetCountry(RemainUsers.iloc[i,2]))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~/anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ~/anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/anaconda3/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/anaconda3/lib/python3.6/http/client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# ~/anaconda3/lib/python3.6/http/client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/anaconda3/lib/python3.6/socket.py in create_connection(address, timeout, source_address)
#     703     err = None
# --> 704     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     705         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# ~/anaconda3/lib/python3.6/urllib/request.py in https_open(self, req)
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#
# ~/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#
# URLError: <urlopen error [Errno -3] Temporary failure in name resolution>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderServiceError                      Traceback (most recent call last)
# <ipython-input-358-f859cb367fbb> in <module>()
#       1 for i in my_range(Country.size, len(RemainUsers)-1, 1):
# ----> 2     Country=np.append(Country,GetCountry(RemainUsers.iloc[i,2]))
#
# <ipython-input-334-e0a71a45def7> in GetCountry(location)
#       4 def GetCountry(location):
#       5     geolocator = Nominatim(timeout=10)
# ----> 6     location = geolocator.geocode(location,language='en')
#       7     if location==None :
#       8         return ('Check')
#
# ~/anaconda3/lib/python3.6/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     191         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#     195
#
# ~/anaconda3/lib/python3.6/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     169                 if "timed out" in message:
#     170                     raise GeocoderTimedOut('Service timed out')
# --> 171             raise GeocoderServiceError(message)
#     172
#     173         if hasattr(page, 'getcode'):
#
# GeocoderServiceError: [Errno -3] Temporary failure in name resolution

# %%
Country=np.append(Country,'NP')

# %%
Country.size
# Out:
# 805

# %%
Country
# Out:
# array([' United States of America', 'Georgia', ' United States of America',
#        ' United States of America', ' Ireland', 'Ireland', 'Check',
#        ' Colombia', ' United States of America', ' Ireland',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United Arab Emirates', ' Lebanon',
#        ' Hungary', ' Finland', 'Ireland', ' United States of America',
#        ' Argentina', ' Colombia', ' Mexico', ' United States of America',
#        ' United States of America', ' Croatia',
#        ' United States of America', ' United States of America',
#        ' Australia', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' Philippines', 'Uganda', 'Luxembourg', 'Argentina', 'Check',
#        ' United States of America', 'Asia', ' United States of America',
#        'Chile', ' Argentina', ' United States of America',
#        ' United States of America', ' Luxembourg', ' Belarus',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' Vietnam', 'Finland',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America', 'Check',
#        'Hungary', ' United States of America', ' Estonia', 'Philippines',
#        ' Estonia', ' Germany', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' Australia', 'Austria', ' Latvia',
#        'Thailand', 'Thailand', 'Paraguay', ' United States of America',
#        ' Germany', ' United Kingdom', 'Slovakia', ' Austria', 'Austria',
#        ' Austria', ' Greece', ' United Arab Emirates',
#        ' United States of America', ' The Netherlands', 'Finland',
#        'Finland', ' Hungary', ' Germany', ' United States of America',
#        ' Lithuania', ' United Kingdom', 'Ireland', 'Switzerland', 'Italy',
#        ' Luxembourg', ' United States of America',
#        ' United States of America', 'Europe', ' Canada', ' Croatia',
#        'Lithuania', 'Ireland', ' Ireland', ' United States of America',
#        ' New Zealand', ' The Netherlands', ' United States of America',
#        ' Argentina', ' Saudi Arabia', ' The Netherlands',
#        ' United Kingdom', 'Romania', ' United States of America',
#        ' Croatia', ' United Kingdom', 'Check', ' United Arab Emirates',
#        ' Kenya', ' United States of America', 'Kenya', 'Ireland',
#        ' United States of America', 'Romania', ' United States of America',
#        ' United States of America', ' Ireland', ' Canada',
#        ' United States of America', ' Switzerland', 'Finland',
#        ' United States of America', ' United States of America', ' Italy',
#        'Ireland', 'Ireland', 'Uruguay', ' Finland', ' Germany',
#        'Switzerland', ' United Arab Emirates', 'Uruguay',
#        ' United States of America', ' United States of America',
#        ' United States of America', 'Philippines', ' United Arab Emirates',
#        ' Mexico', ' RSA', ' Latvia', ' Germany',
#        ' United States of America', ' United States of America', 'Finland',
#        ' Mexico', 'Estonia', 'Greece', 'Finland', 'Ireland',
#        ' United States of America', ' Argentina',
#        ' United States of America', ' Romania',
#        ' United States of America', 'Switzerland', 'Argentina',
#        ' United Kingdom', ' Switzerland', ' United States of America',
#        ' United States of America', ' Canada', 'Iceland', ' Argentina',
#        ' United States of America', ' United States of America',
#        ' Ireland', 'Bangladesh', ' Argentina', ' United States of America',
#        ' Serbia', 'Italy', ' United States of America',
#        'Trinidad and Tobago', ' United Kingdom', ' Ireland',
#        ' United States of America', ' United States of America',
#        ' United Arab Emirates', ' United Arab Emirates',
#        ' United States of America', ' Australia',
#        ' United States of America', ' Austria', ' Belarus', 'Finland',
#        'Finland', ' United States of America', ' Mexico', ' Colombia',
#        ' United Kingdom', 'Ireland', ' United States of America',
#        ' United States of America', ' United States of America', 'Finland',
#        'Czechia', 'Switzerland', 'Switzerland',
#        ' United States of America', 'Ireland', ' Uruguay',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' Slovakia', ' Ireland', ' Italy',
#        ' United States of America', 'Argentina',
#        ' United States of America', ' United States of America',
#        ' United States of America', 'Romania', 'Finland', 'Finland',
#        ' United States of America', ' United States of America', 'Check',
#        ' United States of America', ' United States of America',
#        ' Switzerland', ' United States of America',
#        ' United States of America', 'Check', 'Ireland',
#        ' United States of America', ' United States of America',
#        ' Ireland', 'Switzerland', ' Canada', 'Ireland', 'Thailand',
#        ' The Netherlands', ' Finland', ' Czechia',
#        ' United States of America', 'Check', ' United States of America',
#        ' Australia', ' United States of America',
#        ' United States of America', 'Switzerland', 'Ireland', ' Romania',
#        ' Greece', ' United States of America', ' Ireland', ' Lithuania',
#        ' United States of America', ' The Netherlands',
#        ' United States of America', ' United Kingdom',
#        ' United States of America', 'Estonia', ' Thailand', 'Finland',
#        ' Mexico', 'Iceland', ' Switzerland', ' Ireland',
#        ' United States of America', 'Bermuda', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' Ireland', ' Thailand', ' Hungary', ' United States of America',
#        ' Uruguay', ' United States of America',
#        ' United States of America', 'Italy', ' United States of America',
#        'Uruguay', ' Ireland', ' Greece', ' Ireland',
#        ' United States of America', 'Finland', ' United States of America',
#        'Ireland', 'Chile', ' Romania', 'Slovakia',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' The Netherlands', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' Ethiopia', ' Italy', ' Iceland', ' Thailand', 'Switzerland',
#        ' Argentina', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America', 'Italy',
#        ' United States of America', 'Italy', 'Check',
#        ' United States of America', ' United States of America', 'Europe',
#        ' United States of America', ' Sweden', 'Ireland', ' Germany',
#        ' Switzerland', 'Finland', ' Peru', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America',
#        'Switzerland', ' Mexico', ' United States of America',
#        ' United States of America', ' Switzerland', ' Germany', 'Romania',
#        ' United States of America', ' United States of America',
#        ' Germany', ' China', 'Georgia', ' United States of America',
#        ' United States of America', 'Czechia', 'Austria', 'Switzerland',
#        'Ireland', 'Finland', ' United States of America', 'Ireland',
#        'Romania', ' Argentina', ' United States of America',
#        ' United Kingdom', 'Czechia', ' United States of America', 'Check',
#        ' United States of America', 'Liechtenstein', ' Switzerland',
#        ' United States of America', ' Finland', 'Finland', ' Ireland',
#        'Ireland', ' Slovakia', 'Finland', 'Check', 'Check', ' Mexico',
#        'Afghanistan', ' Romania', ' Italy', ' The Netherlands',
#        ' United Arab Emirates', ' United States of America', 'Finland',
#        'Uruguay', ' Bosnia and Herzegovina', ' United Arab Emirates',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America', 'Finland',
#        ' The Netherlands', 'Finland', ' United States of America',
#        ' United States of America', ' Canada', ' Argentina',
#        ' United States of America', 'Ireland', 'Finland', ' Serbia',
#        ' Colombia', ' United States of America',
#        ' United States of America', ' United States of America', ' France',
#        ' Estonia', ' United States of America',
#        ' United States of America', 'Romania', ' United States of America',
#        'Check', ' United States of America', ' United States of America',
#        'Switzerland', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' Finland', ' Romania', 'Italy', 'Czechia', ' The Netherlands',
#        'Romania', 'Croatia', ' United Kingdom', 'Ireland', 'Greenland',
#        ' The Netherlands', ' United States of America',
#        ' United States of America', ' Switzerland', ' Switzerland',
#        'Austria', ' Canada', ' United States of America',
#        ' United States of America', ' United States of America', 'Italy',
#        ' Slovenia', ' Taiwan', ' United States of America', ' RSA',
#        ' Ireland', ' United States of America', ' Switzerland',
#        ' United States of America', ' United Kingdom',
#        ' United Arab Emirates', ' United States of America',
#        ' United Arab Emirates', ' United Kingdom',
#        ' United States of America', ' Ireland', 'Check', 'Austria',
#        ' United States of America', 'Finland', ' United States of America',
#        ' Austria', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United Kingdom', 'Lithuania', ' RSA',
#        'Belarus', ' Argentina', 'Guatemala', ' United States of America',
#        ' Finland', 'Romania', ' United States of America',
#        ' United Kingdom', ' Ireland', ' RSA', 'Check', 'Switzerland',
#        'Georgia', ' United Kingdom', 'Iceland', ' The Netherlands',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' Guinea', ' Australia',
#        ' United States of America', 'Check', ' United States of America',
#        'Ireland', ' Austria', ' United States of America',
#        ' United States of America', ' United States of America', ' Serbia',
#        ' Latvia', ' United Kingdom', 'Hungary',
#        ' United States of America', ' Italy', ' Romania',
#        ' United States of America', 'Argentina',
#        ' United States of America', ' United States of America',
#        ' United States of America', 'Italy', ' Switzerland', ' Italy',
#        ' United States of America', ' United States of America',
#        'Switzerland', ' Romania', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' Romania', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' Australia', ' United States of America', ' Ireland', 'Czechia',
#        ' Italy', 'Switzerland', ' The Netherlands', ' Serbia', 'Romania',
#        'Serbia', 'Philippines', ' Ireland', ' Greece',
#        ' United States of America', ' Chile', ' Finland',
#        ' The Netherlands', ' RSA', ' The Netherlands', ' Greece',
#        'Bulgaria', ' United States of America', ' United Arab Emirates',
#        'Switzerland', 'Check', ' Italy', ' United States of America',
#        'Finland', 'Africa', ' Slovenia', ' United Kingdom', ' Bangladesh',
#        ' United States of America', ' United States of America',
#        ' Switzerland', ' Russia', ' United Arab Emirates', 'Hungary',
#        ' Hungary', ' RSA', ' Latvia', ' Serbia', ' RSA', 'Check', ' RSA',
#        ' United States of America', ' RSA', 'Austria', ' Greece',
#        'Lithuania', ' United States of America', 'South Korea',
#        ' United Kingdom', 'Lithuania', ' United States of America',
#        ' Cambodia', 'Europe', ' Latvia', 'Estonia', ' Greece',
#        ' Lithuania', ' United States of America', 'Check', ' Hungary',
#        ' Argentina', 'Romania', 'Bulgaria', ' United States of America',
#        'Ireland', 'Switzerland', ' Finland', ' Switzerland',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' Romania',
#        ' United States of America', ' Argentina',
#        ' United States of America', ' France', ' United States of America',
#        ' United States of America', ' Croatia', ' Lithuania',
#        ' United States of America', ' United States of America', ' RSA',
#        ' Argentina', ' United States of America', 'Finland', 'Finland',
#        ' United States of America', 'Iceland', ' United States of America',
#        'Europe', ' United States of America', 'Argentina',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America', 'Ireland',
#        ' Israel', 'Uruguay', 'Check', 'Check', ' United States of America',
#        ' United States of America', 'Check', ' RSA', 'Czechia',
#        ' United States of America', ' Chile', 'Italy',
#        ' United States of America', ' Macedonia',
#        ' United States of America', ' RSA', ' United States of America',
#        ' United States of America', ' RSA', ' Mexico',
#        ' United States of America', 'Check', ' Japan', 'Cuba',
#        ' Switzerland', ' Greece', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' Paraguay', ' United Kingdom', ' United States of America',
#        ' United States of America', ' RSA', 'Check', 'Croatia',
#        ' United Kingdom', 'Finland', ' United States of America',
#        ' United States of America', 'Ireland', ' Haiti',
#        ' United States of America', ' United States of America',
#        'Argentina', ' Italy', 'Ireland', ' Kenya',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' Lithuania', 'Finland', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', 'Czechia', ' United Arab Emirates',
#        ' United States of America', ' United States of America', 'Check',
#        ' United States of America', ' United Arab Emirates',
#        ' United States of America', ' Latvia', ' Serbia',
#        ' United States of America', ' United States of America', ' Mexico',
#        ' United Kingdom', ' Greece', ' Germany', 'Colombia', 'Serbia',
#        ' Mexico', ' United States of America', ' Mexico',
#        ' United States of America', ' Mali', ' D.R.',
#        ' United States of America', 'Check', ' United States of America',
#        'Austria', ' United States of America', 'Hungary',
#        ' United States of America', ' Hungary', ' Argentina',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' United Arab Emirates', ' France',
#        'Finland', ' United States of America', 'Switzerland',
#        ' United States of America', 'Costa Rica',
#        ' United States of America', ' Switzerland',
#        ' United States of America', ' Finland', 'United Arab Emirates',
#        'Austria', ' Switzerland', 'Chile', 'Check', 'Italy',
#        ' United States of America', ' United States of America',
#        ' Iceland', 'Europe', ' Switzerland', ' Mexico', 'Egypt',
#        ' United States of America', ' Chile', ' United States of America',
#        ' RSA', ' United States of America', ' United States of America',
#        ' United States of America', ' United States of America',
#        ' United States of America', 'Luxembourg', 'Argentina',
#        ' United States of America', 'Switzerland',
#        ' United States of America', ' United States of America', 'Check',
#        ' United States of America', 'Italy', ' Bulgaria', ' Spain',
#        ' Mexico', ' United States of America', ' United States of America',
#        'Check', ' Philippines', ' Ireland', 'Colombia', 'Costa Rica',
#        ' United States of America', ' United States of America', ' Canada',
#        ' United States of America', ' United States of America',
#        ' Vanuatu', 'Iceland', ' United States of America', ' Mexico',
#        ' United States of America', 'Philippines', 'Italy',
#        ' United States of America', 'Italy', ' United States of America',
#        'Check', ' United States of America', ' Australia', ' Iceland',
#        ' United States of America', ' United States of America', ' Mexico',
#        ' United States of America', ' United States of America',
#        ' United States of America', ' Philippines', ' China',
#        'Philippines', ' United States of America',
#        ' United States of America', ' United States of America', 'Iran',
#        ' United States of America', 'Check'],
#       dtype='<U32')

# %%
value = [
    ('US', 'United States'),
    ('AF', 'Afghanistan'),
    ('AL', 'Albania'),
    ('DZ', 'Algeria'),
    ('AS', 'American Samoa'),
    ('AD', 'Andorra'),
    ('AO', 'Angola'),
    ('AI', 'Anguilla'),
    ('AQ', 'Antarctica'),
    ('AG', 'Antigua And Barbuda'),
    ('AR', 'Argentina'),
    ('AM', 'Armenia'),
    ('AW', 'Aruba'),
    ('AU', 'Australia'),
    ('AT', 'Austria'),
    ('AZ', 'Azerbaijan'),
    ('BS', 'Bahamas'),
    ('BH', 'Bahrain'),
    ('BD', 'Bangladesh'),
    ('BB', 'Barbados'),
    ('BY', 'Belarus'),
    ('BE', 'Belgium'),
    ('BZ', 'Belize'),
    ('BJ', 'Benin'),
    ('BM', 'Bermuda'),
    ('BT', 'Bhutan'),
    ('BO', 'Bolivia'),
    ('BA', 'Bosnia And Herzegowina'),
    ('BW', 'Botswana'),
    ('BV', 'Bouvet Island'),
    ('BR', 'Brazil'),
    ('BN', 'Brunei Darussalam'),
    ('BG', 'Bulgaria'),
    ('BF', 'Burkina Faso'),
    ('BI', 'Burundi'),
    ('KH', 'Cambodia'),
    ('CM', 'Cameroon'),
    ('CA', 'Canada'),
    ('CV', 'Cape Verde'),
    ('KY', 'Cayman Islands'),
    ('CF', 'Central African Rep'),
    ('TD', 'Chad'),
    ('CL', 'Chile'),
    ('CN', 'China'),
    ('CX', 'Christmas Island'),
    ('CC', 'Cocos Islands'),
    ('CO', 'Colombia'),
    ('KM', 'Comoros'),
    ('CG', 'Congo'),
    ('CK', 'Cook Islands'),
    ('CR', 'Costa Rica'),
    ('CI', 'Cote D`ivoire'),
    ('HR', 'Croatia'),
    ('CU', 'Cuba'),
    ('CY', 'Cyprus'),
    ('CZ', 'Czech Republic'),
    ('DK', 'Denmark'),
    ('DJ', 'Djibouti'),
    ('DM', 'Dominica'),
    ('DO', 'Dominican Republic'),
    ('TP', 'East Timor'),
    ('EC', 'Ecuador'),
    ('EG', 'Egypt'),
    ('SV', 'El Salvador'),
    ('GQ', 'Equatorial Guinea'),
    ('ER', 'Eritrea'),
    ('EE', 'Estonia'),
    ('ET', 'Ethiopia'),
    ('FK', 'Falkland Islands (Malvinas)'),
    ('FO', 'Faroe Islands'),
    ('FJ', 'Fiji'),
    ('FI', 'Finland'),
    ('FR', 'France'),
    ('GF', 'French Guiana'),
    ('PF', 'French Polynesia'),
    ('TF', 'French S. Territories'),
    ('GA', 'Gabon'),
    ('GM', 'Gambia'),
    ('GE', 'Georgia'),
    ('DE', 'Germany'),
    ('GH', 'Ghana'),
    ('GI', 'Gibraltar'),
    ('GR', 'Greece'),
    ('GL', 'Greenland'),
    ('GD', 'Grenada'),
    ('GP', 'Guadeloupe'),
    ('GU', 'Guam'),
    ('GT', 'Guatemala'),
    ('GN', 'Guinea'),
    ('GW', 'Guinea-bissau'),
    ('GY', 'Guyana'),
    ('HT', 'Haiti'),
    ('HN', 'Honduras'),
    ('HK', 'Hong Kong'),
    ('HU', 'Hungary'),
    ('IS', 'Iceland'),
    ('IN', 'India'),
    ('ID', 'Indonesia'),
    ('IR', 'Iran'),
    ('IQ', 'Iraq'),
    ('IE', 'Ireland'),
    ('IL', 'Israel'),
    ('IT', 'Italy'),
    ('JM', 'Jamaica'),
    ('JP', 'Japan'),
    ('JO', 'Jordan'),
    ('KZ', 'Kazakhstan'),
    ('KE', 'Kenya'),
    ('KI', 'Kiribati'),
    ('KP', 'Korea (North)'),
    ('KR', 'Korea (South)'),
    ('KW', 'Kuwait'),
    ('KG', 'Kyrgyzstan'),
    ('LA', 'Laos'),
    ('LV', 'Latvia'),
    ('LB', 'Lebanon'),
    ('LS', 'Lesotho'),
    ('LR', 'Liberia'),
    ('LY', 'Libya'),
    ('LI', 'Liechtenstein'),
    ('LT', 'Lithuania'),
    ('LU', 'Luxembourg'),
    ('MO', 'Macau'),
    ('MK', 'Macedonia'),
    ('MG', 'Madagascar'),
    ('MW', 'Malawi'),
    ('MY', 'Malaysia'),
    ('MV', 'Maldives'),
    ('ML', 'Mali'),
    ('MT', 'Malta'),
    ('MH', 'Marshall Islands'),
    ('MQ', 'Martinique'),
    ('MR', 'Mauritania'),
    ('MU', 'Mauritius'),
    ('YT', 'Mayotte'),
    ('MX', 'Mexico'),
    ('FM', 'Micronesia'),
    ('MD', 'Moldova'),
    ('MC', 'Monaco'),
    ('MN', 'Mongolia'),
    ('MS', 'Montserrat'),
    ('MA', 'Morocco'),
    ('MZ', 'Mozambique'),
    ('MM', 'Myanmar'),
    ('NA', 'Namibia'),
    ('NR', 'Nauru'),
    ('NP', 'Nepal'),
    ('NL', 'Netherlands'),
    ('AN', 'Netherlands Antilles'),
    ('NC', 'New Caledonia'),
    ('NZ', 'New Zealand'),
    ('NI', 'Nicaragua'),
    ('NE', 'Niger'),
    ('NG', 'Nigeria'),
    ('NU', 'Niue'),
    ('NF', 'Norfolk Island'),
    ('MP', 'Northern Mariana Islands'),
    ('NO', 'Norway'),
    ('OM', 'Oman'),
    ('PK', 'Pakistan'),
    ('PW', 'Palau'),
    ('PA', 'Panama'),
    ('PG', 'Papua New Guinea'),
    ('PY', 'Paraguay'),
    ('PE', 'Peru'),
    ('PH', 'Philippines'),
    ('PN', 'Pitcairn'),
    ('PL', 'Poland'),
    ('PT', 'Portugal'),
    ('PR', 'Puerto Rico'),
    ('QA', 'Qatar'),
    ('RE', 'Reunion'),
    ('RO', 'Romania'),
    ('RU', 'Russian Federation'),
    ('RW', 'Rwanda'),
    ('KN', 'Saint Kitts And Nevis'),
    ('LC', 'Saint Lucia'),
    ('VC', 'St Vincent/Grenadines'),
    ('WS', 'Samoa'),
    ('SM', 'San Marino'),
    ('ST', 'Sao Tome'),
    ('SA', 'Saudi Arabia'),
    ('SN', 'Senegal'),
    ('SC', 'Seychelles'),
    ('SL', 'Sierra Leone'),
    ('SG', 'Singapore'),
    ('SK', 'Slovakia'),
    ('SI', 'Slovenia'),
    ('SB', 'Solomon Islands'),
    ('SO', 'Somalia'),
    ('ZA', 'South Africa'),
    ('ES', 'Spain'),
    ('LK', 'Sri Lanka'),
    ('SH', 'St. Helena'),
    ('PM', 'St.Pierre'),
    ('SD', 'Sudan'),
    ('SR', 'Suriname'),
    ('SZ', 'Swaziland'),
    ('SE', 'Sweden'),
    ('CH', 'Switzerland'),
    ('SY', 'Syrian Arab Republic'),
    ('TW', 'Taiwan'),
    ('TJ', 'Tajikistan'),
    ('TZ', 'Tanzania'),
    ('TH', 'Thailand'),
    ('TG', 'Togo'),
    ('TK', 'Tokelau'),
    ('TO', 'Tonga'),
    ('TT', 'Trinidad And Tobago'),
    ('TN', 'Tunisia'),
    ('TR', 'Turkey'),
    ('TM', 'Turkmenistan'),
    ('TV', 'Tuvalu'),
    ('UG', 'Uganda'),
    ('UA', 'Ukraine'),
    ('AE', 'United Arab Emirates'),
    ('UK', 'United Kingdom'),
    ('UY', 'Uruguay'),
    ('UZ', 'Uzbekistan'),
    ('VU', 'Vanuatu'),
    ('VA', 'Vatican City State'),
    ('VE', 'Venezuela'),
    ('VN', 'Viet Nam'),
    ('VG', 'Virgin Islands (British)'),
    ('VI', 'Virgin Islands (U.S.)'),
    ('EH', 'Western Sahara'),
    ('YE', 'Yemen'),
    ('YU', 'Yugoslavia'),
    ('ZR', 'Zaire'),
    ('ZM', 'Zambia'),
    ('ZW', 'Zimbabwe')
]

# %%
Country=np.array([])

# %%
for country in value:
    #print(country)
    Country=np.append(Country,country[1])

# %%
Country
# Out:
# array(['United States', 'Afghanistan', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica',
#        'Antigua And Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia And Herzegowina', 'Botswana',
#        'Bouvet Island', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Central African Rep', 'Chad',
#        'Chile', 'China', 'Christmas Island', 'Cocos Islands', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Cote D`ivoire',
#        'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor',
#        'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Ethiopia', 'Falkland Islands (Malvinas)',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana',
#        'French Polynesia', 'French S. Territories', 'Gabon', 'Gambia',
#        'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guinea',
#        'Guinea-bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq',
#        'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kiribati', 'Korea (North)', 'Korea (South)',
#        'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
#        'Macau', 'Macedonia', 'Madagascar', 'Malawi', 'Malaysia',
#        'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique',
#        'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia',
#        'Moldova', 'Monaco', 'Mongolia', 'Montserrat', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'Netherlands Antilles', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'Niue', 'Norfolk Island',
#        'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Reunion',
#        'Romania', 'Russian Federation', 'Rwanda', 'Saint Kitts And Nevis',
#        'Saint Lucia', 'St Vincent/Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome', 'Saudi Arabia', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia',
#        'South Africa', 'Spain', 'Sri Lanka', 'St. Helena', 'St.Pierre',
#        'Sudan', 'Suriname', 'Swaziland', 'Sweden', 'Switzerland',
#        'Syrian Arab Republic', 'Taiwan', 'Tajikistan', 'Tanzania',
#        'Thailand', 'Togo', 'Tokelau', 'Tonga', 'Trinidad And Tobago',
#        'Tunisia', 'Turkey', 'Turkmenistan', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'Uruguay', 'Uzbekistan',
#        'Vanuatu', 'Vatican City State', 'Venezuela', 'Viet Nam',
#        'Virgin Islands (British)', 'Virgin Islands (U.S.)',
#        'Western Sahara', 'Yemen', 'Yugoslavia', 'Zaire', 'Zambia',
#        'Zimbabwe'],
#       dtype='<U32')
