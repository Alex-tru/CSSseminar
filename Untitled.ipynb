# %%
import pickle
import pandas as pd

# %%
Dict=pickle.load(open('networkAnswers.pickle','rb'))

# %%
Dict['United States']
# Out:
# {'Afghanistan': 199,
#  'Albania': 289,
#  'Algeria': 569,
#  'American Samoa': 5,
#  'Argentina': 7545,
#  'Armenia': 1402,
#  'Australia': 46190,
#  'Austria': 6849,
#  'Azerbaijan': 487,
#  'Bahamas': 44,
#  'Bangladesh': 4087,
#  'Barbados': 27,
#  'Belarus': 2815,
#  'Belgium': 11814,
#  'Belize': 38,
#  'Bermuda': 221,
#  'Bolivia': 787,
#  'Brazil': 23482,
#  'Bulgaria': 4495,
#  'Cambodia': 684,
#  'Cameroon': 151,
#  'Canada': 78623,
#  'Cape Verde': 11,
#  'Chile': 2344,
#  'China': 13811,
#  'Colombia': 2925,
#  'Costa Rica': 1045,
#  'Croatia': 2941,
#  'Cuba': 268,
#  'Cyprus': 680,
#  'Czech Republic': 7710,
#  'Denmark': 11753,
#  'Dominica': 0,
#  'Dominican Republic': 888,
#  'Ecuador': 498,
#  'Egypt': 4208,
#  'Eritrea': 1,
#  'Ethiopia': 221,
#  'Fiji': 78,
#  'Finland': 4481,
#  'France': 25762,
#  'Georgia': 1965,
#  'Germany': 59111,
#  'Ghana': 304,
#  'Greece': 4746,
#  'Grenada': 3,
#  'Guam': 5,
#  'Guatemala': 278,
#  'Guyana': 30,
#  'Haiti': 20,
# ...

# %%
USMigration=pd.read_csv("../USMigrationCountryWiseCSE.csv")

# %%
keys=USMigration.Country.values.tolist()
values=USMigration.Value.values.tolist()
Migration = dict(zip(keys, values))

# %%
Migration
# Out:
# {'Afghanistan': 873,
#  'Albania': 264,
#  'Algeria': 429,
#  'American Samoa': 56,
#  'Argentina': 1970,
#  'Armenia': 863,
#  'Australia': 2156,
#  'Austria': 1163,
#  'Azerbaijan': 417,
#  'Bahamas': 271,
#  'Bangladesh': 2490,
#  'Barbados': 699,
#  'Belarus': 1686,
#  'Belgium': 1206,
#  'Belize': 345,
#  'Bermuda': 250,
#  'Bolivia': 627,
#  'Brazil': 3891,
#  'Bulgaria': 876,
#  'Cambodia': 1964,
#  'Cameroon': 535,
#  'Canada': 18621,
#  'Cape Verde': 130,
#  'Chile': 1098,
#  'China': 55109,
#  'Colombia': 5009,
#  'Costa Rica': 726,
#  'Croatia': 312,
#  'Cuba': 5597,
#  'Cyprus': 183,
#  'Czech Republic': 465,
#  'Denmark': 603,
#  'Dominica': 169,
#  'Dominican Republic': 2735,
#  'Ecuador': 2005,
#  'Egypt': 2096,
#  'Eritrea': 225,
#  'Ethiopia': 1399,
#  'Fiji': 409,
#  'Finland': 622,
#  'France': 5529,
#  'Georgia': 236,
#  'Germany': 20065,
#  'Ghana': 1545,
#  'Greece': 1961,
#  'Grenada': 249,
#  'Guam': 1906,
#  'Guatemala': 1893,
#  'Guyana': 2473,
# ...
